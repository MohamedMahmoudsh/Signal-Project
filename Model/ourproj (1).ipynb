# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02392.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06072.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01653.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04619.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01155.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01698.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03841.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06055.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05321.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00118.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05789.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08568.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01878.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00819.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04650.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05986.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09092.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01830.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06887.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04008.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06434.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04102.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07463.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09342.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05524.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00877.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04148.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04583.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00457.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05160.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09388.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02104.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07156.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00010.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06440.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04209.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01403.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05835.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02085.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01522.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06477.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04336.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07402.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04908.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04795.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08169.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02278.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04623.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07790.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03640.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06980.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05673.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09544.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09450.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03900.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07119.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08436.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03488.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02998.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10241.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00169.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03482.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04097.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05079.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06848.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07534.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01554.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03944.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05483.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04491.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09834.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06327.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03149.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00975.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03642.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02764.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07575.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07152.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06657.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00609.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08727.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03851.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10598.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01979.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02149.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09790.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07481.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10110.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10135.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08037.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08492.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03789.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01789.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09815.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06068.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06090.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09086.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01702.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01189.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09005.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05329.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09544.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08302.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00648.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00504.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09833.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10423.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04696.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03658.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04596.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00722.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05035.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07459.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03692.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01470.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08394.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01934.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10044.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04592.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06759.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08814.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07797.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09083.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00793.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01636.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10327.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04732.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09812.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01427.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06951.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08536.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08230.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09479.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04702.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06895.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08290.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04648.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02778.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04841.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02981.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05714.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09606.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00202.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09711.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01866.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08663.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07077.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04905.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01570.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07383.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04851.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03970.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10433.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02521.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04782.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07420.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00783.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02504.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03288.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03915.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03941.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01070.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03722.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05969.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05799.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01356.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00773.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09385.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05672.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02754.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01579.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00562.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08568.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01775.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00084.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09857.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03636.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03564.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03214.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02597.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04327.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08769.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05466.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07877.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00071.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03835.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01614.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03394.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00538.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02747.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08013.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07018.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04585.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08667.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02495.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03354.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05037.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10016.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04002.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09934.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10104.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03721.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07262.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05131.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04455.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08176.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01434.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01649.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07182.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07650.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10375.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06347.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07218.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04080.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00305.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01573.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10475.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08944.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05262.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00576.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02235.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05779.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05498.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01920.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01252.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08146.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05458.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09128.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09966.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04728.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04705.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09523.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00585.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00670.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02761.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04740.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06011.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04917.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04862.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09495.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04029.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02121.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09535.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05128.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03633.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06277.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02642.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03938.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01887.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06263.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01306.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05164.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01641.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00961.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05226.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08714.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05073.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09666.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00369.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01463.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02841.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01085.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04851.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05168.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01172.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02785.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00718.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09077.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09619.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00305.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00693.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07736.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09301.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00629.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09573.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04112.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10106.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06772.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04796.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07376.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09201.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02171.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00342.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06598.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01647.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02626.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00646.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03044.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09999.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08959.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01043.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09389.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03666.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06085.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02471.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01778.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01165.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04538.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06136.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05052.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05866.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10545.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03877.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01931.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04538.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04317.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05993.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02204.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07896.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05399.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09322.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03017.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05489.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05425.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04549.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09299.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06852.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08721.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04365.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09565.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02540.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05621.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08160.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07377.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01125.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08794.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01133.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02723.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08855.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10178.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05070.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01622.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04098.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00370.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00638.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09516.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02536.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00595.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00209.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10579.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06039.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06405.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01787.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08418.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00759.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08253.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00642.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03258.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09376.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02414.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00538.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00355.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07139.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03098.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03643.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01283.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01865.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10259.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04648.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06625.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07330.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06015.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03955.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06409.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06446.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03983.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00269.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00299.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00557.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03012.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00335.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02388.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10292.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05791.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09284.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02770.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02683.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06320.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00354.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03843.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08535.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09644.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01615.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08892.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09964.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08925.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03073.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04637.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03594.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02499.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03291.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05896.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10357.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08256.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10532.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01836.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04505.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06031.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08760.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07992.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05535.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06510.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02114.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00515.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00087.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07788.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05651.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05959.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05689.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06627.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05963.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06196.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02646.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02226.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07631.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00110.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05287.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04347.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02383.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00669.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06640.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06869.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06649.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10210.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04083.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09186.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04758.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08071.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00636.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08140.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06356.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00193.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03075.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10356.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06464.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02502.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05754.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04931.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07104.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06719.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05773.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08705.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08436.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06158.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02763.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07103.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07233.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08532.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09499.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09431.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10127.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10426.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08225.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06735.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05369.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07629.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09380.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07253.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07232.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07598.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05339.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02519.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04101.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10316.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07357.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02242.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08161.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10572.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05219.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07977.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00145.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03317.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09608.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08590.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09174.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05198.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10011.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03603.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06908.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07703.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09388.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00473.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09971.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04987.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01513.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07890.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00113.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05571.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02102.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01350.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07189.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07230.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10141.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03829.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04453.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00655.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09522.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07196.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04625.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07913.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00828.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10018.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06120.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03028.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07622.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10198.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09769.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08401.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07843.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06824.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09499.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05471.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04663.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06061.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02473.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09990.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04857.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10564.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00282.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00493.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02845.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06410.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10318.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08634.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08694.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08357.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00071.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10384.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08807.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03371.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07743.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09691.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07666.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09928.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06444.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04262.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00339.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04038.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02352.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04824.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04838.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07988.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10019.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00111.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07136.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02382.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09153.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02942.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03972.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00705.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03500.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00005.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01398.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06993.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03366.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06741.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00521.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05645.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08423.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04953.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00702.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04822.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01873.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06459.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00440.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08574.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08136.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09485.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08352.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01942.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00051.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10445.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08726.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08467.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00422.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03226.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03393.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06936.mat
# ...
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01603.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07763.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09260.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08598.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05646.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00619.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02531.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03667.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08180.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05132.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08804.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06197.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07704.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03849.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00841.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04511.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08288.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10200.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07088.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01657.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05361.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02086.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05288.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04129.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00220.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02069.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02113.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02283.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02795.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06881.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05081.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08489.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10459.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01585.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10542.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08648.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07772.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08152.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05032.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08577.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01332.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00989.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10615.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01625.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10009.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02641.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07013.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10347.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06632.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01005.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06720.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00479.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10202.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02465.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10225.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09072.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07034.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03888.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02618.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07022.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05384.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04782.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09496.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04200.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04015.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09262.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00997.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06137.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00897.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00808.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09393.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10019.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09129.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10496.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06938.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06781.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07927.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03487.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02810.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07636.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03678.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07328.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09374.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03313.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08897.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10217.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05874.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01230.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00524.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09418.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10444.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02891.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03045.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06692.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05568.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09206.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03267.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00465.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05504.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07644.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07012.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01527.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02100.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03625.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06990.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03933.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09979.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09605.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02613.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03697.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06783.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03232.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00878.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09886.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00047.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10399.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06221.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02318.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08725.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09370.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08666.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08160.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04832.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01701.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09776.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08951.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02822.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07297.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07094.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09792.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01600.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06182.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02377.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05743.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00056.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06217.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09759.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10506.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00292.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04507.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00839.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10491.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06769.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09259.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09626.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06754.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04934.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02005.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02917.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02751.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01733.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02275.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06042.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10048.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04663.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS10003.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03168.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00484.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01733.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00942.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03661.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05356.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06633.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07563.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03704.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01238.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03102.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03216.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04786.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS02756.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06325.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04591.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04781.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03713.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00140.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03413.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08780.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04372.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00513.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07224.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01251.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01380.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS00494.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS01784.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS04719.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS05205.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS03884.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS09443.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06281.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS08193.hea
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS07774.mat
# /kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing/JS06490.hea
# /kaggle/input/my-dir/imp.csv

# %%
import os

# %%
os.getcwd()
# Out:
# '/kaggle/working'

# %%
#os.removedirs('/kaggle/working/Recurent_model')
os.mkdir('Recurent_model')
os.mkdir('Convloution_model')

# %%
os.chdir('/kaggle/input/chapmanshaoxing-12lead-ecg-database/WFDB_ChapmanShaoxing')

# %%
import matplotlib.pyplot as plt
from tensorflow import data 
import wfdb as sig
import keras
from keras.models import Sequential , load_model
from keras.layers import Dense,BatchNormalization, Activation, Dropout, Conv1D, GlobalAveragePooling1D, MaxPooling1D , SimpleRNN , LSTM , Input
from keras import regularizers
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint , EarlyStopping
from keras.optimizers import Adam
import seaborn as sns
#from keras.utils import np_utils
# Out:
# 2024-05-18 21:36:35.150874: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-18 21:36:35.150970: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-18 21:36:35.291825: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def find_the_best_threshold(model , X, Y ):
    """
    To find the best threshold I need the model , X , Y to selct the best threshold passed on acciracy
    The function return a list of tuble the sample of tuple (accuracy at threshold , threshold )
   """
    threshold_VS_accuracy = []
    Thresholds = np.linspace(0,1 ,100)
    Predection = model(X).numpy()
    for Threshold in Thresholds:
        Y_hat = Predection >= Threshold
        Y_hat = Y_hat.reshape((-1,))
        True_rate =  Y_hat == Y
        threshold_VS_accuracy.append((Threshold ,  True_rate.sum()))
    return threshold_VS_accuracy

# %%
def evaluate(Predection, X ,Y, threshold):
    """
    This function evaluate True postive rate  , False postive rate at a certain threshold.
    This function is used to evaluate the ROC curve.
    This function return (FP_rate , TP_rate)
    """
    condition = Predection >=threshold
    Y_hat =condition.reshape((-1,))
    TP = Y_hat[Y==1].sum()
    TP_rate = TP / len(Y_hat[Y==1])
    FP = Y_hat[Y==0].sum()
    FP_rate = FP/len(Y_hat[Y==0])
    #return FP , TP          #Test Condition
    return FP_rate , TP_rate

# %%
def AUC_For_model(ROC_Pair):
    """
    This Function is used to evaluate the area under ROC curve which used to evaluate the model
    bassed on ROC curve.
    return AUC
    """
    AUC = 0
    for i in range(1 , len(ROC_Pair)):
        AUC += abs(ROC_Pair[i,0] - ROC_Pair[i-1,0] ) * (ROC_Pair[i,1] + ROC_Pair[i-1,1] )
    return AUC/2

# %%
def ROC_Pair_FN(model ,X , Y):
    """
    This function is uesed in ploting the ROC curve
    This function needs model , X , Y
    output (FP_rate , TP_rate )
    """
    Predection  = model(X).numpy()
    Thresholds = np.linspace(0,1 ,100)
    ROC_pair = []
    for Threshold in Thresholds:
        pair = evaluate(Predection , X , Y , Threshold)
        ROC_pair.append(pair)
    return np.c_[np.array(ROC_pair) , Thresholds]

# %%
def preprocess(dat):
    data_dir = list(dat['directory'])
    data_signal = map(read_signal , data_dir)
    data_signal = list(data_signal)
    data_signal = np.array(data_signal)
    data_dict = {'SR' : 0 , 'SB': 1  }
    encoded_label = dat['diagnosis'].map(data_dict)
    return np.array(data_signal)  , np.array(encoded_label)

# %%
def read_signal(record):
    tes = sig.rdrecord(record,sampfrom=0 , sampto=5000)
    signal = tes.__dict__['p_signal'][::,0]
    return signal

# %%
df = pd.read_csv('/kaggle/input/my-dir/imp.csv').iloc[:: , 1:3]
train , test = train_test_split(df , train_size=.8 ,random_state=1002)
train.reset_index(inplace = True)
test.reset_index(inplace = True)
plt.plot(read_signal(train['directory'][0]))
train['diagnosis'][0]
# Out:
# 'SR'

# %%
Class_summary = df.groupby('diagnosis').count() * 100 / len(df)
Class_summary
# Out:
#            directory
# diagnosis
# SB         61.715247
# SR         38.284753

# %% [markdown]
# ### Data preperation for model

# %% [markdown]
# ### Label preperation for model

# %%
x_train , y_train = preprocess(train)
x_test  , y_test  = preprocess(test)

# %%
optimizer = Adam()
Recurent_model = Sequential()
Recurent_model.add(Input(shape = (100 , 50)))
Recurent_model.add(LSTM(64))
Recurent_model.add(Dense(32 , activation= 'relu'))
Recurent_model.add(Dense(1 , activation= 'sigmoid'))
Recurent_model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
Recurent_model_x_train = x_train.reshape((-1 ,100 , 50))
Recurent_model_x_test  = x_test.reshape((-1 ,100 , 50))

# %%
Recurent_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 64)             │        29,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,553 (123.25 KB)
#  Trainable params: 31,553 (123.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
Best_Recurent_model_directory = '/kaggle/working/Recurent_model/best.keras'
Best_Recurent_model_checkpoint = ModelCheckpoint(
    filepath=Best_Recurent_model_directory ,save_best_only=True 
)

# %%
Recurent_model_hist = Recurent_model.fit(x = Recurent_model_x_train , y = y_train , batch_size= 32 , epochs =  50 ,validation_data=(Recurent_model_x_test, y_test),
         callbacks = [Best_Recurent_model_checkpoint])
# Out:
# Epoch 1/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6045 - loss: 0.6764 - val_accuracy: 0.6092 - val_loss: 0.6731
# Epoch 2/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6153 - loss: 0.6599 - val_accuracy: 0.6134 - val_loss: 0.6605
# Epoch 3/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6408 - loss: 0.6364 - val_accuracy: 0.6120 - val_loss: 0.6583
# Epoch 4/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6589 - loss: 0.6152 - val_accuracy: 0.6751 - val_loss: 0.5996
# Epoch 5/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7118 - loss: 0.5588 - val_accuracy: 0.7857 - val_loss: 0.4381
# Epoch 6/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8098 - loss: 0.3978 - val_accuracy: 0.8697 - val_loss: 0.3248
# Epoch 7/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8771 - loss: 0.2959 - val_accuracy: 0.9020 - val_loss: 0.2413
# Epoch 8/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9090 - loss: 0.2152 - val_accuracy: 0.9230 - val_loss: 0.2223
# Epoch 9/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9220 - loss: 0.2166 - val_accuracy: 0.9272 - val_loss: 0.2318
# Epoch 10/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9309 - loss: 0.1804 - val_accuracy: 0.9384 - val_loss: 0.1562
# Epoch 11/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9457 - loss: 0.1517 - val_accuracy: 0.9342 - val_loss: 0.1917
# Epoch 12/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9615 - loss: 0.1116 - val_accuracy: 0.9468 - val_loss: 0.1461
# Epoch 13/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9512 - loss: 0.1125 - val_accuracy: 0.9538 - val_loss: 0.1376
# Epoch 14/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9644 - loss: 0.0973 - val_accuracy: 0.9454 - val_loss: 0.1917
# Epoch 15/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9566 - loss: 0.1228 - val_accuracy: 0.9384 - val_loss: 0.1753
# Epoch 16/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9614 - loss: 0.1040 - val_accuracy: 0.9524 - val_loss: 0.1430
# Epoch 17/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9761 - loss: 0.0778 - val_accuracy: 0.9538 - val_loss: 0.1304
# Epoch 18/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9809 - loss: 0.0681 - val_accuracy: 0.9580 - val_loss: 0.1179
# Epoch 19/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9696 - loss: 0.1027 - val_accuracy: 0.9524 - val_loss: 0.1490
# Epoch 20/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9730 - loss: 0.0730 - val_accuracy: 0.9622 - val_loss: 0.1430
# Epoch 21/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9674 - loss: 0.0880 - val_accuracy: 0.9692 - val_loss: 0.1003
# Epoch 22/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9859 - loss: 0.0527 - val_accuracy: 0.9678 - val_loss: 0.0910
# Epoch 23/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9820 - loss: 0.0496 - val_accuracy: 0.9552 - val_loss: 0.2252
# Epoch 24/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9691 - loss: 0.0916 - val_accuracy: 0.9636 - val_loss: 0.0997
# Epoch 25/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9771 - loss: 0.0700 - val_accuracy: 0.9636 - val_loss: 0.1129
# Epoch 26/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9836 - loss: 0.0494 - val_accuracy: 0.9524 - val_loss: 0.1470
# Epoch 27/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9809 - loss: 0.0517 - val_accuracy: 0.9552 - val_loss: 0.1421
# Epoch 28/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9846 - loss: 0.0428 - val_accuracy: 0.9398 - val_loss: 0.1663
# Epoch 29/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9806 - loss: 0.0583 - val_accuracy: 0.9608 - val_loss: 0.1290
# Epoch 30/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9833 - loss: 0.0483 - val_accuracy: 0.9720 - val_loss: 0.0842
# Epoch 31/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9902 - loss: 0.0405 - val_accuracy: 0.9608 - val_loss: 0.1261
# Epoch 32/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9856 - loss: 0.0405 - val_accuracy: 0.9678 - val_loss: 0.1024
# Epoch 33/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9868 - loss: 0.0380 - val_accuracy: 0.9706 - val_loss: 0.1046
# Epoch 34/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9894 - loss: 0.0309 - val_accuracy: 0.9650 - val_loss: 0.1046
# Epoch 35/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9904 - loss: 0.0291 - val_accuracy: 0.9622 - val_loss: 0.1293
# Epoch 36/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9881 - loss: 0.0298 - val_accuracy: 0.9510 - val_loss: 0.1362
# Epoch 37/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9922 - loss: 0.0293 - val_accuracy: 0.9538 - val_loss: 0.1279
# Epoch 38/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9819 - loss: 0.0524 - val_accuracy: 0.9706 - val_loss: 0.0965
# Epoch 39/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9880 - loss: 0.0358 - val_accuracy: 0.9552 - val_loss: 0.1141
# Epoch 40/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9914 - loss: 0.0258 - val_accuracy: 0.9608 - val_loss: 0.1537
# Epoch 41/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9793 - loss: 0.0646 - val_accuracy: 0.9524 - val_loss: 0.1405
# Epoch 42/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9905 - loss: 0.0277 - val_accuracy: 0.9622 - val_loss: 0.1749
# Epoch 43/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9922 - loss: 0.0250 - val_accuracy: 0.9692 - val_loss: 0.1139
# Epoch 44/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9927 - loss: 0.0161 - val_accuracy: 0.9566 - val_loss: 0.2576
# Epoch 45/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9883 - loss: 0.0341 - val_accuracy: 0.9496 - val_loss: 0.1829
# Epoch 46/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9890 - loss: 0.0284 - val_accuracy: 0.9650 - val_loss: 0.1212
# Epoch 47/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9908 - loss: 0.0275 - val_accuracy: 0.9678 - val_loss: 0.1150
# Epoch 48/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9923 - loss: 0.0340 - val_accuracy: 0.9748 - val_loss: 0.0995
# Epoch 49/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9905 - loss: 0.0276 - val_accuracy: 0.9664 - val_loss: 0.0921
# Epoch 50/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9929 - loss: 0.0165 - val_accuracy: 0.9692 - val_loss: 0.0953

# %%
Recurent_model.save('/kaggle/working/Recurent_model/Last.keras')

# %%
best_Recurent_model = load_model('/kaggle/working/Recurent_model/best.keras')
ROC_For_best_Recurent_model = ROC_Pair_FN(best_Recurent_model ,Recurent_model_x_test,y_test )

# %%
ROC_For_Recurent_model = ROC_Pair_FN(Recurent_model , Recurent_model_x_test,y_test)

# %%
plt.figure(figsize=(7,7))
plt.style.use('ggplot')
plt.scatter(ROC_For_best_Recurent_model [:: , 0] , ROC_For_best_Recurent_model [:: ,1 ]  , marker = '.' , c = 'red',s =200)
plt.plot(ROC_For_Recurent_model[::,0] , ROC_For_Recurent_model[:: , 1]  , c = 'orange' ,  label = f"AUC last = {AUC_For_model(ROC_For_Recurent_model):.4f}" )
plt.plot(ROC_For_best_Recurent_model [:: , 0] ,  ROC_For_best_Recurent_model [:: , 1], c = 'magenta' , label = f"AUC best = {AUC_For_model(ROC_For_best_Recurent_model):.4f}" )
plt.plot([0,1.001] , [0,1.001 ]  ,lw=2, linestyle='--' , color = 'navy'  )
plt.xlim([-0.01, 1.05])
plt.ylim([-0.01, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right" ,fontsize="15" )
plt.show()

# %% [markdown]
# ### From ROC Curve the best model and last model seems to be identical
# ### The best model gives the least loss
# ### We will use the best model

# %% [markdown]
# ### Searching for best Threshold

# %%
Threshold_vs_accuracy_In_Recurent_model = find_the_best_threshold(best_Recurent_model , Recurent_model_x_test , y_test )

# %%
Threshold_vs_accuracy_In_Recurent_model  = np.array(Threshold_vs_accuracy_In_Recurent_model)
condition = Threshold_vs_accuracy_In_Recurent_model[:: , 1] ==Threshold_vs_accuracy_In_Recurent_model[:: , 1].max()
Threshold_vs_accuracy_In_Recurent_model[condition,0]
Recurent_model_accuracy = Threshold_vs_accuracy_In_Recurent_model[:: , 1].max() / len(y_test)
print(Recurent_model_accuracy)
# Out:
# 0.9747899159663865

# %%
Threshold_vs_accuracy_In_Recurent_model[condition,0]
# Out:
# array([0.53535354, 0.58585859])

# %% [markdown]
# ### Confusion matrix for best threshold
# ### We will choose 0.56565657

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
Y_hat = best_Recurent_model(Recurent_model_x_test) >=0.58585859
plt.figure(figsize=(5,5))
plt.title("Confusion matrix for Recurent Network")
sns.heatmap(confusion_matrix(y_test , Y_hat ),cmap = sns.dark_palette("#69d",10, reverse=True, as_cmap=True),annot=True,linewidth=1 ,fmt=".0f");
plt.xlabel('Predicted')
plt.ylabel('Actual');

# %%
from sklearn.metrics import f1_score
print(f"F1_Score For Recurrent Model= {f1_score(y_test , Y_hat) }")
# Out:
# F1_Score For Recurrent Model= 0.9789227166276346

# %% [markdown]
# ### 1D convloution model

# %%
CNN_model = Sequential()
CNN_model.add(Conv1D(128, 55, activation='relu', input_shape=(5000, 1)))
CNN_model.add(MaxPooling1D(10))
CNN_model.add(Dropout(0.5))
CNN_model.add(Conv1D(128, 25, activation='relu'))
CNN_model.add(MaxPooling1D(5))
CNN_model.add(Dropout(0.5))
CNN_model.add(Conv1D(128, 10, activation='relu'))
CNN_model.add(MaxPooling1D(5))
CNN_model.add(Dropout(0.5))
CNN_model.add(Conv1D(128, 5, activation='relu'))
CNN_model.add(GlobalAveragePooling1D())
# model.add(Flatten())
CNN_model.add(Dense(256, kernel_initializer='normal', activation='relu'))
CNN_model.add(Dropout(0.5))
CNN_model.add(Dense(128, kernel_initializer='normal', activation='relu'))
CNN_model.add(Dropout(0.5))
CNN_model.add(Dense(64, kernel_initializer='normal', activation='relu'))
CNN_model.add(Dropout(0.5))
CNN_model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
CNN_model.compile(loss = 'binarycrossentropy')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
opt  = keras.optimizers.Adam(.001)
metrics = [keras.metrics.Accuracy()]
CNN_model.compile(loss =keras.losses.binary_crossentropy  , optimizer= opt , metrics = ['accuracy']  )

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
CNN_hist = CNN_model.fit(x = x_train , y = y_train , batch_size= 32 , epochs =  50 ,validation_data=(x_test , y_test) , callbacks= [early_stopping] )
# Out:
# Epoch 1/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 24s 138ms/step - accuracy: 0.6116 - loss: 0.6610 - val_accuracy: 0.9664 - val_loss: 0.3887
# Epoch 2/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9039 - loss: 0.2718 - val_accuracy: 0.9846 - val_loss: 0.0586
# Epoch 3/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9842 - loss: 0.0598 - val_accuracy: 0.9804 - val_loss: 0.0467
# Epoch 4/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9859 - loss: 0.0382 - val_accuracy: 0.9902 - val_loss: 0.0612
# Epoch 5/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9874 - loss: 0.0460 - val_accuracy: 0.9846 - val_loss: 0.0362
# Epoch 6/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9837 - loss: 0.0497 - val_accuracy: 0.9790 - val_loss: 0.0465
# Epoch 7/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9914 - loss: 0.0393 - val_accuracy: 0.9846 - val_loss: 0.0312
# Epoch 8/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9913 - loss: 0.0311 - val_accuracy: 0.9860 - val_loss: 0.0352
# Epoch 9/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9903 - loss: 0.0307 - val_accuracy: 0.9706 - val_loss: 0.0774
# Epoch 10/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9866 - loss: 0.0632 - val_accuracy: 0.9818 - val_loss: 0.0340
# Epoch 11/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9891 - loss: 0.0289 - val_accuracy: 0.9860 - val_loss: 0.0302
# Epoch 12/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9902 - loss: 0.0315 - val_accuracy: 0.9874 - val_loss: 0.0344
# Epoch 13/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9893 - loss: 0.0281 - val_accuracy: 0.9762 - val_loss: 0.0646
# Epoch 14/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9900 - loss: 0.0287 - val_accuracy: 0.9832 - val_loss: 0.0330
# Epoch 15/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9927 - loss: 0.0212 - val_accuracy: 0.9874 - val_loss: 0.0270
# Epoch 16/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9897 - loss: 0.0328 - val_accuracy: 0.9790 - val_loss: 0.0419
# Epoch 17/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9935 - loss: 0.0205 - val_accuracy: 0.9818 - val_loss: 0.0547
# Epoch 18/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9936 - loss: 0.0235 - val_accuracy: 0.9818 - val_loss: 0.0376
# Epoch 19/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9917 - loss: 0.0398 - val_accuracy: 0.9846 - val_loss: 0.0292
# Epoch 20/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9926 - loss: 0.0213 - val_accuracy: 0.9944 - val_loss: 0.0310
# Epoch 21/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9912 - loss: 0.0289 - val_accuracy: 0.9860 - val_loss: 0.0354
# Epoch 22/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9916 - loss: 0.0283 - val_accuracy: 0.9832 - val_loss: 0.0450
# Epoch 23/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9899 - loss: 0.0330 - val_accuracy: 0.9846 - val_loss: 0.0437
# Epoch 24/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9947 - loss: 0.0220 - val_accuracy: 0.9874 - val_loss: 0.0255
# Epoch 25/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9933 - loss: 0.0259 - val_accuracy: 0.9818 - val_loss: 0.0302
# Epoch 26/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9968 - loss: 0.0159 - val_accuracy: 0.9846 - val_loss: 0.0522
# Epoch 27/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9940 - loss: 0.0139 - val_accuracy: 0.9874 - val_loss: 0.0294
# Epoch 28/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9961 - loss: 0.0110 - val_accuracy: 0.9902 - val_loss: 0.0187
# Epoch 29/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9861 - loss: 0.0488 - val_accuracy: 0.9804 - val_loss: 0.0540
# Epoch 30/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9919 - loss: 0.0315 - val_accuracy: 0.9860 - val_loss: 0.0335
# Epoch 31/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9925 - loss: 0.0261 - val_accuracy: 0.9902 - val_loss: 0.0296
# Epoch 32/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9939 - loss: 0.0165 - val_accuracy: 0.9902 - val_loss: 0.0222
# Epoch 33/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9919 - loss: 0.0200 - val_accuracy: 0.9818 - val_loss: 0.0559
# Epoch 34/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9966 - loss: 0.0108 - val_accuracy: 0.9930 - val_loss: 0.0180
# Epoch 35/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9915 - loss: 0.0242 - val_accuracy: 0.9846 - val_loss: 0.0623
# Epoch 36/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9910 - loss: 0.0335 - val_accuracy: 0.9832 - val_loss: 0.0446
# Epoch 37/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9942 - loss: 0.0148 - val_accuracy: 0.9846 - val_loss: 0.0399
# Epoch 38/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9967 - loss: 0.0163 - val_accuracy: 0.9804 - val_loss: 0.0646
# Epoch 39/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9941 - loss: 0.0194 - val_accuracy: 0.9846 - val_loss: 0.0437
# Epoch 40/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9925 - loss: 0.0331 - val_accuracy: 0.9832 - val_loss: 0.0670
# Epoch 41/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9930 - loss: 0.0131 - val_accuracy: 0.9874 - val_loss: 0.0227
# Epoch 42/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9948 - loss: 0.0132 - val_accuracy: 0.9860 - val_loss: 0.0333
# Epoch 43/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9936 - loss: 0.0266 - val_accuracy: 0.9846 - val_loss: 0.0427
# Epoch 44/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9941 - loss: 0.0134 - val_accuracy: 0.9944 - val_loss: 0.0267

# %%
predictions = CNN_model.predict(x_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(y_test,predictions )
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.6f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')

plt.xlim([-0.02, 1.0])
plt.ylim([-0.02, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
accuracy_Vs_Threshold_IN_CNN_model = np.array(find_the_best_threshold(CNN_model , x_test, y_test ))/[1 , 714]

# %%
best_threshold_for_CNN_filter = accuracy_Vs_Threshold_IN_CNN_model[:: , 1] == accuracy_Vs_Threshold_IN_CNN_model[:: , 1].max() 
best_threshold_for_CNN = accuracy_Vs_Threshold_IN_CNN_model[best_threshold_for_CNN_filter ]
best_threshold_for_CNN
# Out:
# array([[0.66666667, 0.99579832],
#        [0.67676768, 0.99579832],
#        [0.68686869, 0.99579832],
#        [0.6969697 , 0.99579832],
#        [0.70707071, 0.99579832],
#        [0.71717172, 0.99579832],
#        [0.72727273, 0.99579832],
#        [0.73737374, 0.99579832]])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
Y_hat = CNN_model(x_test) >=  0.66666667
plt.figure(figsize=(5,5))
plt.title('Confusion matrix for CNN model')
sns.heatmap(confusion_matrix(y_test , Y_hat ),cmap = sns.dark_palette("#69d",10, reverse=True, as_cmap=True),annot=True,linewidth=1 ,fmt=".0f");
plt.xlabel('Predicted')
plt.ylabel('Actual');

# %%
print(f"F1 score for CNN model = {f1_score(y_test , Y_hat )}")
# Out:
# F1 score for CNN model = 0.9964994165694282

# %%
CNN_model.save('/kaggle/working/Convloution_model/CNN_model.keras')
